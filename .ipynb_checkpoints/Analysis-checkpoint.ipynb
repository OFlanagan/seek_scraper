# %%
import pandas as pd
import re
import string

# %%
df = pd.read_csv("listings_df.csv")

# %%
test_string = df["main_text"][0]
print(test_string)
# Out:
# <div class="job-template__wrapper">
# <div class="tempborder">
# <div class="templogo"><img alt="Bluefin Resources" src="https://seekcdn.com/templates/14724871_30_top.png"/></div>
# <div class="temptoptext">Data Analytics Recruitment Solutions</div>
# <div class="tempmargin">
# <h1 class="jobtitle">Financial Crime Analysts - SAS, SQL, R or Python </h1>
# <ul class="templatebullet">
# <li>Leading Australian Bank </li>
# <li>CBD location </li>
# <li>Innovative and forward thinking organisation </li>
# </ul>
# <div class="templatetext">
# <p>A number of opportunities exist for Financial Crime Analysts within a leading financial institution in Sydney.</p>
# <p>In this role you will be involved in collecting, analysing and modelling data which relates to financial crime, information security &amp; security risks. This includes involvement in investigating incidents through data mining and analysis, researching
#           financial crime, information security and security related trends and emerging issues, and identifying triggers to alert suspicious behaviour. </p>
# <p>Duties would include;</p>
# <ul>
# <li>Identify patterns &amp; characteristics within data to drive the development of fraud mitigation strategies</li>
# <li>Optimisation and development of new detection scenarios</li>
# <li>Utilise statistical modelling/machine learning to drive predictive capability</li>
# <li>Work with key business partners to improve detection performance</li>
# </ul>
# <p>Requirements: </p>
# <ul>
# <li>A degree in a numerate discipline such as Statistics, Mathematics, Actuarial Studies</li>
# <li>Programming skills in either SAS, R, SQL or Python</li>
# <li>Ideally 1+ years commercial analytics experience, however strong graduates will be considered </li>
# <li>Experience manipulating and mining large datasets to draw insights</li>
# <li>An interest in games such as chess, poker or blackjack would be beneficial - a similar thought process goes into solving financial crime</li>
# <li>Strong communication skills</li>
# </ul>
# <p>Please apply online or for more information please contact Alex Slocombe on <a class="_2ZKuACf" data-contact-match="true" href="tel:02 9270 2602">02 9270 2602</a>.</p>
# <p>Only candidates with valid Australian work rights will be considered.</p>
# <p style="text-align:center;">IMPORTANT: By submitting your email address and any other personal information when you APPLY to a job, you consent to such information being collected, held, used and disclosed in accordance with our COLLECTIONS NOTICE and PRIVACY POLICY.</p>
# <p style="text-align:center;">http://www.bluefinresources.com.au/privacy-policy</p>
# </div>
# <div class="details"> </div>
# </div>
# <div class="tempweb">www.bluefinresources.com.au</div>
# </div>
# </div>

# %%
test_string
# Out:
# '<div class="job-template__wrapper">\n<div class="tempborder">\n<div class="templogo"><img alt="Bluefin Resources" src="https://seekcdn.com/templates/14724871_30_top.png"/></div>\n<div class="temptoptext">Data Analytics Recruitment Solutions</div>\n<div class="tempmargin">\n<h1 class="jobtitle">Financial Crime Analysts - SAS, SQL, R or Python </h1>\n<ul class="templatebullet">\n<li>Leading Australian Bank </li>\n<li>CBD location </li>\n<li>Innovative and forward thinking organisation </li>\n</ul>\n<div class="templatetext">\n<p>A number of opportunities exist for Financial Crime Analysts within a leading financial institution in Sydney.</p>\n<p>In this role you will be involved in collecting, analysing and modelling data which relates to financial crime, information security &amp; security risks. This includes involvement in investigating incidents through data mining and analysis, researching\n          financial crime, information security and security related trends and emerging issues, and identifying triggers to alert suspicious behaviour. </p>\n<p>Duties would include;</p>\n<ul>\n<li>Identify patterns &amp; characteristics within data to drive the development of fraud mitigation strategies</li>\n<li>Optimisation and development of new detection scenarios</li>\n<li>Utilise statistical modelling/machine learning to drive predictive capability</li>\n<li>Work with key business partners to improve detection performance</li>\n</ul>\n<p>Requirements: </p>\n<ul>\n<li>A degree in a numerate discipline such as Statistics, Mathematics, Actuarial Studies</li>\n<li>Programming skills in either SAS, R, SQL or Python</li>\n<li>Ideally 1+ years commercial analytics experience, however strong graduates will be considered </li>\n<li>Experience manipulating and mining large datasets to draw insights</li>\n<li>An interest in games such as chess, poker or blackjack would be beneficial - a similar thought process goes into solving financial crime</li>\n<li>Strong communication skills</li>\n</ul>\n<p>Please apply online or for more information please contact Alex Slocombe on <a class="_2ZKuACf" data-contact-match="true" href="tel:02 9270 2602">02 9270 2602</a>.</p>\n<p>Only candidates with valid Australian work rights will be considered.</p>\n<p style="text-align:center;">IMPORTANT: By submitting your email address and any other personal information when you APPLY to a job, you consent to such information being collected, held, used and disclosed in accordance with our COLLECTIONS NOTICE and PRIVACY POLICY.</p>\n<p style="text-align:center;">http://www.bluefinresources.com.au/privacy-policy</p>\n</div>\n<div class="details"> </div>\n</div>\n<div class="tempweb">www.bluefinresources.com.au</div>\n</div>\n</div>'

# %%
pattern = re.compile(r'<.*>')
matches = pattern.finditer(test_string)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 35), match='<div class="job-template__wrapper">'>
# <re.Match object; span=(36, 60), match='<div class="tempborder">'>
# <re.Match object; span=(61, 175), match='<div class="templogo"><img alt="Bluefin Resources>
# <re.Match object; span=(176, 243), match='<div class="temptoptext">Data Analytics Recruitme>
# <re.Match object; span=(244, 268), match='<div class="tempmargin">'>
# <re.Match object; span=(269, 344), match='<h1 class="jobtitle">Financial Crime Analysts - S>
# <re.Match object; span=(345, 372), match='<ul class="templatebullet">'>
# <re.Match object; span=(373, 406), match='<li>Leading Australian Bank </li>'>
# <re.Match object; span=(407, 429), match='<li>CBD location </li>'>
# <re.Match object; span=(430, 484), match='<li>Innovative and forward thinking organisation >
# <re.Match object; span=(485, 490), match='</ul>'>
# <re.Match object; span=(491, 517), match='<div class="templatetext">'>
# <re.Match object; span=(518, 635), match='<p>A number of opportunities exist for Financial >
# <re.Match object; span=(636, 639), match='<p>'>
# <re.Match object; span=(1046, 1050), match='</p>'>
# <re.Match object; span=(1051, 1079), match='<p>Duties would include;</p>'>
# <re.Match object; span=(1080, 1084), match='<ul>'>
# <re.Match object; span=(1085, 1201), match='<li>Identify patterns &amp; characteristics withi>
# <re.Match object; span=(1202, 1266), match='<li>Optimisation and development of new detection>
# <re.Match object; span=(1267, 1353), match='<li>Utilise statistical modelling/machine learnin>
# <re.Match object; span=(1354, 1427), match='<li>Work with key business partners to improve de>
# <re.Match object; span=(1428, 1433), match='</ul>'>
# <re.Match object; span=(1434, 1455), match='<p>Requirements: </p>'>
# <re.Match object; span=(1456, 1460), match='<ul>'>
# <re.Match object; span=(1461, 1554), match='<li>A degree in a numerate discipline such as Sta>
# <re.Match object; span=(1555, 1614), match='<li>Programming skills in either SAS, R, SQL or P>
# <re.Match object; span=(1615, 1718), match='<li>Ideally 1+ years commercial analytics experie>
# <re.Match object; span=(1719, 1794), match='<li>Experience manipulating and mining large data>
# <re.Match object; span=(1795, 1940), match='<li>An interest in games such as chess, poker or >
# <re.Match object; span=(1941, 1977), match='<li>Strong communication skills</li>'>
# <re.Match object; span=(1978, 1983), match='</ul>'>
# <re.Match object; span=(1984, 2154), match='<p>Please apply online or for more information pl>
# <re.Match object; span=(2155, 2231), match='<p>Only candidates with valid Australian work rig>
# <re.Match object; span=(2232, 2505), match='<p style="text-align:center;">IMPORTANT: By submi>
# <re.Match object; span=(2506, 2589), match='<p style="text-align:center;">http://www.bluefinr>
# <re.Match object; span=(2590, 2596), match='</div>'>
# <re.Match object; span=(2597, 2625), match='<div class="details"> </div>'>
# <re.Match object; span=(2626, 2632), match='</div>'>
# <re.Match object; span=(2633, 2687), match='<div class="tempweb">www.bluefinresources.com.au<>
# <re.Match object; span=(2688, 2694), match='</div>'>
# <re.Match object; span=(2695, 2701), match='</div>'>

# %%
print(test_string)
# Out:
# <div class="job-template__wrapper">
# <div class="tempborder">
# <div class="templogo"><img alt="Bluefin Resources" src="https://seekcdn.com/templates/14724871_30_top.png"/></div>
# <div class="temptoptext">Data Analytics Recruitment Solutions</div>
# <div class="tempmargin">
# <h1 class="jobtitle">Financial Crime Analysts - SAS, SQL, R or Python </h1>
# <ul class="templatebullet">
# <li>Leading Australian Bank </li>
# <li>CBD location </li>
# <li>Innovative and forward thinking organisation </li>
# </ul>
# <div class="templatetext">
# <p>A number of opportunities exist for Financial Crime Analysts within a leading financial institution in Sydney.</p>
# <p>In this role you will be involved in collecting, analysing and modelling data which relates to financial crime, information security &amp; security risks. This includes involvement in investigating incidents through data mining and analysis, researching
#           financial crime, information security and security related trends and emerging issues, and identifying triggers to alert suspicious behaviour. </p>
# <p>Duties would include;</p>
# <ul>
# <li>Identify patterns &amp; characteristics within data to drive the development of fraud mitigation strategies</li>
# <li>Optimisation and development of new detection scenarios</li>
# <li>Utilise statistical modelling/machine learning to drive predictive capability</li>
# <li>Work with key business partners to improve detection performance</li>
# </ul>
# <p>Requirements: </p>
# <ul>
# <li>A degree in a numerate discipline such as Statistics, Mathematics, Actuarial Studies</li>
# <li>Programming skills in either SAS, R, SQL or Python</li>
# <li>Ideally 1+ years commercial analytics experience, however strong graduates will be considered </li>
# <li>Experience manipulating and mining large datasets to draw insights</li>
# <li>An interest in games such as chess, poker or blackjack would be beneficial - a similar thought process goes into solving financial crime</li>
# <li>Strong communication skills</li>
# </ul>
# <p>Please apply online or for more information please contact Alex Slocombe on <a class="_2ZKuACf" data-contact-match="true" href="tel:02 9270 2602">02 9270 2602</a>.</p>
# <p>Only candidates with valid Australian work rights will be considered.</p>
# <p style="text-align:center;">IMPORTANT: By submitting your email address and any other personal information when you APPLY to a job, you consent to such information being collected, held, used and disclosed in accordance with our COLLECTIONS NOTICE and PRIVACY POLICY.</p>
# <p style="text-align:center;">http://www.bluefinresources.com.au/privacy-policy</p>
# </div>
# <div class="details"> </div>
# </div>
# <div class="tempweb">www.bluefinresources.com.au</div>
# </div>
# </div>

# %%
pattern = re.compile(r'<(.*?)>')
test_string = pattern.sub("",test_string)
print(test_string)
# Out:
# Data Analytics Recruitment Solutions
#
# Financial Crime Analysts - SAS, SQL, R or Python
#
# Leading Australian Bank
# CBD location
# Innovative and forward thinking organisation
#
#
# A number of opportunities exist for Financial Crime Analysts within a leading financial institution in Sydney.
# In this role you will be involved in collecting, analysing and modelling data which relates to financial crime, information security &amp; security risks. This includes involvement in investigating incidents through data mining and analysis, researching
#           financial crime, information security and security related trends and emerging issues, and identifying triggers to alert suspicious behaviour.
# Duties would include;
#
# Identify patterns &amp; characteristics within data to drive the development of fraud mitigation strategies
# Optimisation and development of new detection scenarios
# Utilise statistical modelling/machine learning to drive predictive capability
# Work with key business partners to improve detection performance
#
# Requirements:
#
# A degree in a numerate discipline such as Statistics, Mathematics, Actuarial Studies
# Programming skills in either SAS, R, SQL or Python
# Ideally 1+ years commercial analytics experience, however strong graduates will be considered
# Experience manipulating and mining large datasets to draw insights
# An interest in games such as chess, poker or blackjack would be beneficial - a similar thought process goes into solving financial crime
# Strong communication skills
#
# Please apply online or for more information please contact Alex Slocombe on 02 9270 2602.
# Only candidates with valid Australian work rights will be considered.
# IMPORTANT: By submitting your email address and any other personal information when you APPLY to a job, you consent to such information being collected, held, used and disclosed in accordance with our COLLECTIONS NOTICE and PRIVACY POLICY.
# http://www.bluefinresources.com.au/privacy-policy
#
#
#
# www.bluefinresources.com.au

# %%
pattern = re.compile(r'\n{2,}')
test_string = pattern.sub('\n',test_string)
print(test_string)
# Out:
# Data Analytics Recruitment Solutions
# Financial Crime Analysts - SAS, SQL, R or Python
# Leading Australian Bank
# CBD location
# Innovative and forward thinking organisation
# A number of opportunities exist for Financial Crime Analysts within a leading financial institution in Sydney.
# In this role you will be involved in collecting, analysing and modelling data which relates to financial crime, information security &amp; security risks. This includes involvement in investigating incidents through data mining and analysis, researching
#           financial crime, information security and security related trends and emerging issues, and identifying triggers to alert suspicious behaviour.
# Duties would include;
# Identify patterns &amp; characteristics within data to drive the development of fraud mitigation strategies
# Optimisation and development of new detection scenarios
# Utilise statistical modelling/machine learning to drive predictive capability
# Work with key business partners to improve detection performance
# Requirements:
# A degree in a numerate discipline such as Statistics, Mathematics, Actuarial Studies
# Programming skills in either SAS, R, SQL or Python
# Ideally 1+ years commercial analytics experience, however strong graduates will be considered
# Experience manipulating and mining large datasets to draw insights
# An interest in games such as chess, poker or blackjack would be beneficial - a similar thought process goes into solving financial crime
# Strong communication skills
# Please apply online or for more information please contact Alex Slocombe on 02 9270 2602.
# Only candidates with valid Australian work rights will be considered.
# IMPORTANT: By submitting your email address and any other personal information when you APPLY to a job, you consent to such information being collected, held, used and disclosed in accordance with our COLLECTIONS NOTICE and PRIVACY POLICY.
# http://www.bluefinresources.com.au/privacy-policy
#
# www.bluefinresources.com.au

# %%
pattern = re.compile(r' {2,}')
test_string = pattern.sub(' ',test_string)
print(test_string)
# Out:
# Data Analytics Recruitment Solutions
# Financial Crime Analysts - SAS, SQL, R or Python
# Leading Australian Bank
# CBD location
# Innovative and forward thinking organisation
# A number of opportunities exist for Financial Crime Analysts within a leading financial institution in Sydney.
# In this role you will be involved in collecting, analysing and modelling data which relates to financial crime, information security &amp; security risks. This includes involvement in investigating incidents through data mining and analysis, researching
#  financial crime, information security and security related trends and emerging issues, and identifying triggers to alert suspicious behaviour.
# Duties would include;
# Identify patterns &amp; characteristics within data to drive the development of fraud mitigation strategies
# Optimisation and development of new detection scenarios
# Utilise statistical modelling/machine learning to drive predictive capability
# Work with key business partners to improve detection performance
# Requirements:
# A degree in a numerate discipline such as Statistics, Mathematics, Actuarial Studies
# Programming skills in either SAS, R, SQL or Python
# Ideally 1+ years commercial analytics experience, however strong graduates will be considered
# Experience manipulating and mining large datasets to draw insights
# An interest in games such as chess, poker or blackjack would be beneficial - a similar thought process goes into solving financial crime
# Strong communication skills
# Please apply online or for more information please contact Alex Slocombe on 02 9270 2602.
# Only candidates with valid Australian work rights will be considered.
# IMPORTANT: By submitting your email address and any other personal information when you APPLY to a job, you consent to such information being collected, held, used and disclosed in accordance with our COLLECTIONS NOTICE and PRIVACY POLICY.
# http://www.bluefinresources.com.au/privacy-policy
#
# www.bluefinresources.com.au

# %%
def clean_string(string):
    pattern = re.compile(r'<(.*?)>')
    string = pattern.sub("",string)
    pattern = re.compile(r'\n{2,}')
    string = pattern.sub('\n',string)
    pattern = re.compile(r' {2,}')
    string = pattern.sub(' ',string)
    return string

def clean_non_standard_string(string):
    pattern = re.compile(r'\n{2,}')
    string = pattern.sub(' ',string)
    pattern = re.compile(r' {2,}')
    string = pattern.sub(' ',string)
    pattern = re.compile(r'\n')
    string = pattern.sub('NEWLINE',string)
    pattern = re.compile(r'\((.*?)\)')
    string = pattern.sub('',string)
    pattern = re.compile(r'\{(.*?)\}')
    string = pattern.sub('',string)
    pattern = re.compile(r'window.SEEK.*')
    string = pattern.sub('',string)
    pattern = re.compile(r'Report this job advertBe careful.*')
    string = pattern.sub("",string)
    pattern = re.compile(r'.*\}')
    string = pattern.sub("",string)
    pattern = re.compile(r'.*for saleVolunteeringAUNZ')
    string = pattern.sub("",string)
    pattern = re.compile(r'NEWLINE')
    string = pattern.sub('\n',string)
    return string

def detect_non_standard_string(string):
    pattern = re.compile(r'\(function\(l,d,j,t\)')
    return pattern.search(string)!=None
    

df["tidied_main_text"] = [clean_non_html_string(string)  if detect_non_standard_string(string) == True else clean_string(string) for string in df["main_text"]]

# %%
for i in range(0,50):
    print(i)
    print(df["tidied_main_text"][i])
# Out:
# 0
#
# Data Analytics Recruitment Solutions
# Financial Crime Analysts - SAS, SQL, R or Python
# Leading Australian Bank
# CBD location
# Innovative and forward thinking organisation
# A number of opportunities exist for Financial Crime Analysts within a leading financial institution in Sydney.
# In this role you will be involved in collecting, analysing and modelling data which relates to financial crime, information security &amp; security risks. This includes involvement in investigating incidents through data mining and analysis, researching
#  financial crime, information security and security related trends and emerging issues, and identifying triggers to alert suspicious behaviour.
# Duties would include;
# Identify patterns &amp; characteristics within data to drive the development of fraud mitigation strategies
# Optimisation and development of new detection scenarios
# Utilise statistical modelling/machine learning to drive predictive capability
# Work with key business partners to improve detection performance
# Requirements:
# A degree in a numerate discipline such as Statistics, Mathematics, Actuarial Studies
# Programming skills in either SAS, R, SQL or Python
# Ideally 1+ years commercial analytics experience, however strong graduates will be considered
# Experience manipulating and mining large datasets to draw insights
# An interest in games such as chess, poker or blackjack would be beneficial - a similar thought process goes into solving financial crime
# Strong communication skills
# Please apply online or for more information please contact Alex Slocombe on 02 9270 2602.
# Only candidates with valid Australian work rights will be considered.
# IMPORTANT: By submitting your email address and any other personal information when you APPLY to a job, you consent to such information being collected, held, used and disclosed in accordance with our COLLECTIONS NOTICE and PRIVACY POLICY.
# http://www.bluefinresources.com.au/privacy-policy
#
# www.bluefinresources.com.au
#
# 1
#
# Data Analyst - R Language
# A role suited to someone growing their I.T career
# 3 month contract with possibility to extend
# Supportive company culture
# This role will be responsible for data analysis from multiple sources, quality management, documentation and reporting for financial analysis for pre-sales data.    You will be required to analyse data from a variety of systems
#  to identify patterns, relationships, connections and associations within the data sets supporting the company’s sales team.    Day to day responsibilities include:
# Supporting the Sales team with pre-sales data and financial analysis.
# Analyse data from many sources and create reports for use internally and with customers.
# Identify and analyse ongoing data issues from various sources.
# Working with data team on various data related initiatives.
#  Skills, knowledge and experience required:
# Proficient skills coding in R language.
# Experience working with MySQL and SQL.
# High level of Microsoft Excel and Microsoft Word.
# Amazon Web Services (AWS) platform and functional experience.
# Strong analytical skills coupled with great attention to detail for data analysis work.
# Experience coding with Python will be highly regarded.
# Ability to work, both independently and as part of a team.
# Excellent communication skills.
# Experience working in the Energy / Utilities domain will be highly regarded.
# alcami Pty Ltd Level 12, 20 Bridge St :: Sydney NSW 2000 P:: + 61 2 9199 5600
#
# 2
#
# Data Analytics Recruitment Solutions
# Financial Crime Analysts - SAS, SQL, R or Python
# Leading Australian Bank
# CBD location
# Innovative and forward thinking organisation
# A number of opportunities exist for Financial Crime Analysts within a leading financial institution in Sydney.
# In this role you will be involved in collecting, analysing and modelling data which relates to financial crime, information security &amp; security risks. This includes involvement in investigating incidents through data mining and analysis, researching
#  financial crime, information security and security related trends and emerging issues, and identifying triggers to alert suspicious behaviour.
# Duties would include;
# Identify patterns &amp; characteristics within data to drive the development of fraud mitigation strategies
# Optimisation and development of new detection scenarios
# Utilise statistical modelling/machine learning to drive predictive capability
# Work with key business partners to improve detection performance
# Requirements:
# A degree in a numerate discipline such as Statistics, Mathematics, Actuarial Studies
# Programming skills in either SAS, R, SQL or Python
# Ideally 1+ years commercial analytics experience, however strong graduates will be considered
# Experience manipulating and mining large datasets to draw insights
# An interest in games such as chess, poker or blackjack would be beneficial - a similar thought process goes into solving financial crime
# Strong communication skills
# Please apply online or for more information please contact Alex Slocombe on 02 9270 2602.
# Only candidates with valid Australian work rights will be considered.
# IMPORTANT: By submitting your email address and any other personal information when you APPLY to a job, you consent to such information being collected, held, used and disclosed in accordance with our COLLECTIONS NOTICE and PRIVACY POLICY.
# http://www.bluefinresources.com.au/privacy-policy
#
# www.bluefinresources.com.au
#
# 3
#
# Python Developer
# JOB DESCRIPTION:
# Design and implement ETL systems in Apache Airflow.
# Experience with scaling data pipelines for large datasets
# Possess data engineering skills with strong: SQL, AirFlow Skills
# Take ownership of the data engineering efforts within the wider team
# Resource should have experience in scalable data pipelines in the AWS or any other cloud environment
# Participate in storyboard and solution design sessions – recommend alternative approaches and best practices, define technical impact, and provide sizing estimates.
# Follow an Agile software development methodology and contribute to all phases of the software development lifecycle and support processes.
# Proficient in Python/Java, BigData Tech, Lightning Component, Integration.
# Proficient in CICD ecosystem using Git and Bamboo
# Skills Required:
# Possess strong Python skills with minimum 3-5 years of core Python development experience.
# Redis Queue and Redis Caching
# Postgres DB experience is preferable
# Cloud computing skills preferably on AWS
# Hands-on development experience in Airflow.
# Hands on data engineering experience with writing SQL for data prep, cleansing using Python or R.
#
#
# 4
#
# Senior Data Engineer (Spark/Python/PySpark) | Fraud Detection Platform
#
# Startup Specialist building platforms in Trading, payments, Analytics etc
# Solve complex "real world" problems with Data Modelling and Big Data processing
# Newly created R&amp;D Data Division
# Unique opportunity for a Senior Data Engineer to have fun and get creative with Real Time Trading Data within an HFT specialist.  Build tools to assist in fraud detection in an ever changing complex environment.   Be a senior figure
#  in a newly created Data Engineering team, with a chance to use your “tools of choice” in building be-spoke Fraud detection products.    Rewards
# Very highly competitive Salary or Daily Rates
# Flexible working environment that’s kind on the out of work commitments
#  What you will Need:
# Experience Engineering similar Data Driven products – extracting insights
# Python
# PySpark / Spark / Scala Spark
# Java /  Scala
# Database Schema Design
# Able to code Risk Models: PySpark / Big Data processing
#    Please apply now for a discrete discussion about this position.
# Naviro Pty Ltd Level 12, 234 George Street Sydney NSW 2000 Darren
# www.naviro.com.au
#
# 5
#
# Risk Management &amp; Compliance Recruitment Solutions
# Digital Analyst
# Work for one of Australia's well-known brands
# Will suit a digital / web analyst with 1 + years exp | Adobe or google analytics
# Competitive salary on offer | Excellent company benefits
# Our client, a respected and well-known brand in their market, are currently experiencing growth in their Digital Performance &amp; Analytics team.
# There is an excellent opportunity for a Digital Analytics specialists to join this team and assist with delivering analytics, insights and reporting to optimise campaign performance.
# Key responsibilities for the role;
# To support customer insight analytics and marketing to deliver analytics and insights to key stakeholders
# To carry out daily activities via the Adobe suite, including Adobe Audience and Adobe Target
# Ensure quality control and oversight of reporting output
# Refine and optimise campaign activities based on post-campaign analysis to maximise profitability
# Proactively engage with stakeholders by supplying customer insights &amp; assist marketing with strategy recommendations
# To plan, document and execute optimisation campaigns based on key business conversion
# To develop and support implementation of digital performance dashboards
# To support the business with adhoc analysis and insights to solve business problems
# To be successful for the role you will have;
# A degree in Actuarial, Maths / Statistics, Engineering, Computer Science, Physics is preferred
# 1 + year experience in web or digital analytics would be highly desirable
# Proven experience in using Adobe Suite, Google Analytics and Tableau
# Experience with SQL, SAS, R or Python would be advantageous
# Proven experience of driving insights from data and presenting the findings to different sets of stakeholders
# Must be technically strong in Microsoft Suite
# Strong written and verbal communication skills
# If this sounds of interest to you, please call Sophie Monaghan immediately on 02 9270 2603 or APPLY via the link
# IMPORTANT: By submitting your email address and any other personal information when you APPLY to a job, you consent to such information being collected, held, used and disclosed in accordance with our COLLECTIONS NOTICE and PRIVACY POLICY.
# http://www.bluefinresources.com.au/privacy-policy
#
# www.bluefinresources.com.au
#
# 6
#
# Data Scientist
# Looking for an up and coming Data Scientist
# Fast growing Tech organisation
# Sydney, CBD
# Role: Data Scientist
# Salary: $95-105k base
# Location: Sydney - R / Python SQL &amp; Data Visualisation
# My client, a fast growing tech company based in Sydney, is looking for an up and coming Data Scientist to join their analytics team. In this team you will be exposed to a variety of data sets ranging from logistical analysis to
#  signal processing. You will be required to be adaptable and have a keen interest in learning new techniques. You need to have a solid understanding of organisational challenges and be commercially aware to excel in this role. Responsibilities:
# Interpret data from disparate of sources, analyse results using statistical techniques.
# Deliver analytics using your mathematics and statistics background (Signal Processing, Logistical analytics)
# Develop statistical models to gain insights and provide information around trends and patterns
# Qualifications:
# Tertiary qualification in a Quantitative discipline (Economics, Statistics, Mathematics)
# Strong working knowledge with large data sets
# Statistical programming experience in Python/R and SQL
# To be part of a fast growing tech organisation in Sydney, working in a fast paced, dynamic, fun and friendly environment - with ambitious plans. Please apply immediately with an up to date CV.
# Or to hear more please get in touch (02) 8986 3139 or jpope@morganmckinley.com.au
# PYTHON / AWS / EXCEL / SQL / R / AZURE / INSIGHT / ANALYST / MODELLING / ANALYST
# Morgan McKinley is acting as an Employment Agency in relation to this vacancy.
#
#
# 7
#
# Data/Business Analyst
# Data/Business Analyst
# Sydney CBD Location
# Emerging Australian owned consultancy brand
# We have an exciting role for a Data/Business Analyst to join an emerging Australian owned consultancy brand, working on-site with a dedicated government client in Sydney CBD.Key responsibilities:
# You will be conducting a Conceptual Design Process for its proposed Research &amp; Development Data Storage and Management solutions. The outcomes required are;
# A user needs analysis report that outlines the findings from the service provider's engagement across the DPI R&amp;D community (including external users of the data) and additional research, identifying gaps and business requirements with regards
#  to R&amp;D data storage and management;
# A 'target state' solution design to address the identified R&amp;D data business requirements, defining how data should be stored and organised in order to enable discoverability, accessibility and reuse, and a roadmap for implementation taking
#  into account the work done so far;
# An information governance framework to guide the establishment of formalised R&amp;D information governance at DPI; and
# A solution assessment document for the recommended data storage and management structure, including validated cost estimates.
# Key skills required for this role:
# 5+ years proven work experience as a data/business analyst or similar role.
# Technical expertise regarding data acquisitions, data transformation, data models, database design development, data mining and segmentation techniques.
# Strong understanding of Data Governance including Data Classification, Data Quality, Data Lineage, Data Protection/Privacy/Security.
# Previous experience with NSW Government Data Policies and Standards highly desirable.
# For more information, please contact Scarlett Cooke on scarlett.cooke@talentinternational.comAPPLY NOW!
#
# 8
#
# Data Analyst Financial Services
# Data Analyst- Financial Services- Sydney CBD We are seeking a Data Analystto join a fast growing Financial services firm based in the heart of the city. The ideal Data Engineer will be join a small team with big plans,
#  who enjoy a flat hierarchy where all ideas are heard. The Data Analyst will be comfortable preparing big data infrastructure to be analysed by Data Scientists. The ideal Data Analyst will design, build and integrate data from various
#  resources, and manages big data. The Data Analystwill be experienced with running some ETL on top of big Datasets and create big data warehouses that can be used for reporting or analysis by data scientists. You are finally used to
#  use different data services on the cloud (ideally from GCP). An amazing role with chance to learn many new things. The requirements of the Data Analyst
# Python/R Skills
# 2+ Years Data Analyst/Engineer/Scientist exposure
# SQL Skills
# Research based mindset
# The ideal Data Engineer will have a clear route of progression from the start and will be a key decision maker for the company.
# To find out more about Progressive Recruitment please visit our website.
#
# Award Winner for:
# Best Medium Recruitment Company of the Year by Recruitment International 2018
# Training &amp; Development Initiative of the Year by Recruitment International 2018
#
#
# 9
#
# Statistician Data Scientist, Analytics, Machine Learning - Data Scientist, Math
# Your Benefits:
# Great Package;
# Generous Bonuses;
# Fun &amp; Positive Environment;
# Training Budgets + Work-Life Balance Options;
# Brand-New and High-Profile Projects;
# Organic Growth Opportunities;
#     You are joining a Data Science and Machine learning thought leader organization based in the CBD area with established best practices in data science and insight analytics and further investments to enhancement of their insight
#  functions. You will come from a strong data analytics / data science background with technical experience across data mining &amp; filtration, statistical data modeling and provision of insight. In return they offer a range of
#  perks, generous bonuses and training budgets, opportunity to speak at important functions and work-life balance options.    To be successful for this role, your CV will need to reflect on following skill-set:
# Commercial Experience as a Data Scientist / Insight Analytics Consultant;
# Education background in Applied Statistics, Mathematics, Acuarial, Econometrics or a similar Data Stat Modeling field;
# Data development experience with Python or R or SQL;
# Experience working on a cloud based data platform such as AWS, Google Cloud, Microsoft Azure or a similar platform;
# Demonstrated experience in data mining, data filtering and building predictive / regression models using different methodologies such as decision trees, time series and/or Bayesian statistics;
#     You can either apply here or send your application directly to Sonia at Sonia@infinitypro.com.au quoting 008IDataScientist. We can be contacted on (02) 9687 1025 for a confidential discussion but please ensure the resume
#  has been sent.
# Please ensure all documents are sent in Microsoft word format.
# www.infinitypro.com.au
#
# 10
#
# Data Analyst - R/SAS - Campaigns - International Brand!
# One of the most recognised brands in the world!
#
# Huge Loyalty Program
#
# 3 Month Contract Initially + Extensions
#
# This is a fantastic opportunity for a Data Analyst to join work on one of the largest Loyalty programs in Australia!  We are looking for someone who is specialised in using data to optimise Campaign performance using
#  a range of modelling and deep dive analysis techniques.This company is an internationally recognised brand with stunning offices and a healthy pipeline of exciting projects. You will need to be
#  able to effectively extract and analyse the performance of campaigns and provide key insights and recommendations for future improvements.This is an initial 3 Month contract with plenty of scope for extensions!Skills and Experience:
# +2 years working as a Campaign Analyst / Insights Analyst / Modellor
# Strong SQL skills
# Data Visulisation: Tableau, Power BI etc
# SAS or R - Modelling/Customer Segmentation
# Previous experience working in Loyalty is prefered
# Experience using a Marketing Automation platforms – SF Marketing Cloud, Unica, SAS CI etc
# Strong stakeholder engagement experience with the ability to build strong relationships while managing expectations in a fast past environment.
# Experience in pre and post campaign analysis.
#  What’s in it for you:This is one of the busiest and most talked about organisations in the country right now. The project has a huge scope for the coming years! You'll be joining a large Agile team
#  with a manager that believes in continual development. This team has excellent staff retention rates and the manager looks for people that want to grow with the company for years to come. If you are intersted please apply now or contact Rebecca on 02 9993 1071 for more information.
# Aurec Technology &amp; Communications focuses on providing a highly specialised human capital sourcing service across Australia and Asia Pacific. Visit our website www.aurec.com
#
# 11
# Data Engineer -- Python, SparkMore jobs from this companyJob DescriptionJob HeaderData Engineer -- Python, SparkAdvertiser: Nithi Research and Management solutionsMore jobs from this companyJob InformationJob Listing Date3 Feb 2019LocationSydney, CBD, Inner West & Eastern SuburbsWork TypeContract/TempClassificationInformation & Communication Technology, Database Development & Administration  Data engineer -- Python My client, a top bank, is currently looking for a mid-level Big Data Engineer to join a challenging project : building a big data platforms for their senior board reporting. It is a great opportunity for you to join a dynamic and experienced crew where you will learn a lot.   This is a short term 3 month contract and may extend up to 12 months . The position is in Sydney CBD.   Requirements - Data Engineer   At least 3 years of relevant hands on coding experience in Python, Hadoop in Data Engineer / Analyst positions Hands on Hadoop experience + Python, Spark, flume Ability to work in team in diverse/ multiple stakeholder environment Experience in working in a fast-paced Agile environment 3years + big data hands-on experience Experience with Data quality/Data cleansing/Data manipulation/Data streaming Strong Python / Java programming background including C++ / Java and Spark Strong software development experience on Linux-based application Cassandra / HBase / HIVE / mapR Familiar with Network protocol  Experience integrating solutions in a complex environment Good working knowledge with CI / CD tools and Devops processes  Skills Python  Java R Data Cleaning Apache Spark Hadoop HBase DevOps Cassandra Big Data If you are interested in this opportunity or looking for a Big Data / Data Science role in Australia, You can either call Kowchi or apply here or email me to hr@nithiresearch.com quoting ref STDATAPYT.I am happy to give you a call to present you the project.The application form will include these questions:Which of the following statements best describes your right to work in Australia?How many years' experience do you have as a software engineer?How many years' experience do you have as a devops engineer?
# 12
#
# Data Analyst
# My client is a medium-sized Aussie consultancy who have been awarded a large piece of work by NSW Government. They are urgently seeking an experienced Data Analyst for this pivotal role. The duration is initially 6 months but this is
#  a large project that is expected to run for at least 12 months. Due to the urgent nature of the position we can only consider applicants with a maximum of a two week notice period. We are submitting resumes to the client on Monday 25th so applications after this time can not be considered. You will work with the Lead Solution Architect to deliver:
# A user needs analysis report that outlines the findings from the service provider’s engagement across the DPI R&amp;D community (including external users of the data) and additional research, identifying gaps and business requirements with regards
#  to R&amp;D data storage and management;
# A ‘target state’ solution design to address the identified R&amp;D data business requirements, defining how data should be stored and organised in order to enable discoverability, accessibility and reuse, and a roadmap for implementation taking
#  into account the work done so far;
# An information governance framework to guide the establishment of formalised R&amp;D information governance at DPI; and
# A solution assessment document for the recommended data storage and management structure, including validated cost estimates.
# You:
# 3+ years experience as a data/business analyst or similar role
# Technical expertise regarding data acquisitions, data transformation, data models, database design development, data mining and segmentation techniques.
# Strong understanding of Data Governance including Data Classification, Data Quality, Data Lineage, Data Protection/Privacy/Security.
# Previous experience with NSW Government Data Policies and Standards highly desirable.
# To be considered for the role click the 'Apply' button or for more information about this role please contact Nick Barwick on 02 9409 4754. Please quote our job reference number: 192697.
# 1 800 People
# Adelaide • Brisbane • Canberra • Melbourne • Perth • Sydney • Hong Kong • Singapore
#
# 13
#
# Data Analyst
# My client is a medium-sized Aussie consultancy who have been awarded a large piece of work by NSW Government. They are urgently seeking an experienced Data Analyst for this pivotal role. The duration is initially 6 months but this is
#  a large project that is expected to run for at least 12 months. Due to the urgent nature of the position we can only consider applicants with a maximum of a two week notice period. We are submitting resumes to the client on Monday 25th so applications after this time can not be considered. You will work with the Lead Solution Architect to deliver:
# A user needs analysis report that outlines the findings from the service provider’s engagement across the DPI R&amp;D community (including external users of the data) and additional research, identifying gaps and business requirements with regards
#  to R&amp;D data storage and management;
# A ‘target state’ solution design to address the identified R&amp;D data business requirements, defining how data should be stored and organised in order to enable discoverability, accessibility and reuse, and a roadmap for implementation taking
#  into account the work done so far;
# An information governance framework to guide the establishment of formalised R&amp;D information governance at DPI; and
# A solution assessment document for the recommended data storage and management structure, including validated cost estimates.
# You:
# 3+ years experience as a data/business analyst or similar role
# Technical expertise regarding data acquisitions, data transformation, data models, database design development, data mining and segmentation techniques.
# Strong understanding of Data Governance including Data Classification, Data Quality, Data Lineage, Data Protection/Privacy/Security.
# Previous experience with NSW Government Data Policies and Standards highly desirable.
# To be considered for the role click the 'Apply' button or for more information about this role please contact Nick Barwick on 02 9409 4754. Please quote our job reference number: 192697.
# 1 800 People
# Adelaide • Brisbane • Canberra • Melbourne • Perth • Sydney • Hong Kong • Singapore
#
# 14
#
# Data Analyst - Banking and Finance
# The Company
# This is a fantastic opportunity for a Data Analyst to join one of the biggest banks in the Sydney CBD.
#
# The Role
# You will be joining an existing experienced team that are delivering a multi-million $ project.
# You will be:
# Working in a team of data analysts / scientists to identify and assess evolving trends, emerging risks and systemic misconduct in financial services and markets
# Designing and advising on processes to collect, manipulate, clean and explore data
# Analyse structured and unstructured data using statistical or machine learning approaches
# Working closely with Senior Analysts to scope, identify and establish appropriate data analysis methodologies for individual research projects
# Communicating analytical findings, including through reports, briefings, presentations and data visualisation
# Providing expert support to stakeholder teams conducting operational data analysis
# Who you are
# Experienced data analyst with history of working within banking and finance
# Good working knowledge of data manipulation and experience in applying statistical or machine learning approaches to data analysis using R, Python or similar tools
# Attentive to detail
# Excellent communication to chase up document owners for missing information
#
# What’s on offer?
# Central location
# 6 month contract
# Great work culture
# Large, well-known bank
#
# Who we are
# The Finite group is a multi-award winning consultancy recognised across Australia and New Zealand for excellence in recruitment for the technology consultancy space. We have 20 years of year on year success. Our teams specialise in the following
#  areas of technology recruitment (contract and permanent): DevOps | Business Intelligence | Big Data | Analytics | Infrastructure | Engineering | Digital; iOS Android| Front End Development| Back End Development | UX | UI | Research | Project
#  Management | Change Management | AdOps | Service Delivery |
# What's next?
# If you would like to be considered, please send applications to Rosanna Cabungcal on  rosannac@finxl.com.au or click the apply button!
#
#
# 15
#
# Data Analyst Wealth Management
# Data Engineer- Financial Services- Sydney CBD We are seeking a Data Engineer to join a fast growing Financial services firm based in the heart of the city. The ideal Data Engineer will be join a small team with big plans,
#  who enjoy a flat hierarchy where all ideas are heard. The Data Engineer will be comfortable preparing big data infrastructure to be analysed by Data Scientists. The ideal Data Engineer will design, build and integrate data from various
#  resources, and manages big data. The Data Engineer will be experienced with running some ETL on top of big Datasets and create big data warehouses that can be used for reporting or analysis by data scientists. You are finally used to
#  use different data services on the cloud (ideally from GCP). An amazing role with chance to learn many new things. The requirements of the Data Engineer
# Python/R Skills
# 2+ Years Data Analyst/Engineer/Scientist exposure
# SQL Skills
# Research based mindset
# The ideal Data Engineer will have a clear route of progression from the start and will be a key decision maker for the company.
# To find out more about Progressive Recruitment please visit our website.
#
# Award Winner for:
# Best Medium Recruitment Company of the Year by Recruitment International 2018
# Training &amp; Development Initiative of the Year by Recruitment International 2018
#
#
# 16
#
# Quant Developer/Analyst
# Looking for a Quant Developer/Analyst to join a leading financial services organisation on an initial 6-month contract, located in Sydney. Exciting opportunity for a Quant Developer to develop risk models, automate manual tasks, engage in software/algorithm
#  development and perform quant analyst responsibilities. The position involves working closely with the Market Risk Group, as you implement a wide range of models and system interfaces.
# Key Responsibilities
# Development in C#, C++, VBA
# Building market risk models
# Working closely with Quant Anlayst, Quant Developers and Traders
# Key Requirements
# Required: Previous experience as a Quant Developer/Analyst in the financial markets space
# Quant Finance educational background/PhD highly desirable
# Technical expertise across at least two of the following: C#, C++, VBA, R, Python
# Strong knowledge of market risk, fixed income, FX trading, commodities
# Excellent communication skills
# Summary
# Competitive daily rate, leading financial services firm, high-performing team.
# To apply please click apply or call Akhil Arya on +61 2 82893216 for a confidential discussion.
#
# www.robertwalters.com.au    |    FIND YOUR PLACE WITH US
#
# 17
#
# Risk Management &amp; Compliance Recruitment Solutions
# Digital Analyst
# Work for one of Australia's well-known brands
# Will suit a digital / web analyst with 1 + years exp | Adobe or google analytics
# Competitive salary on offer | Excellent company benefits
# Our client, a respected and well-known brand in their market, are currently experiencing growth in their Digital Performance &amp; Analytics team.
# There is an excellent opportunity for a Digital Analytics specialists to join this team and assist with delivering analytics, insights and reporting to optimise campaign performance.
# Key responsibilities for the role;
# To support customer insight analytics and marketing to deliver analytics and insights to key stakeholders
# To carry out daily activities via the Adobe suite, including Adobe Audience and Adobe Target
# Ensure quality control and oversight of reporting output
# Refine and optimise campaign activities based on post-campaign analysis to maximise profitability
# Proactively engage with stakeholders by supplying customer insights &amp; assist marketing with strategy recommendations
# To plan, document and execute optimisation campaigns based on key business conversion
# To develop and support implementation of digital performance dashboards
# To support the business with adhoc analysis and insights to solve business problems
# To be successful for the role you will have;
# A degree in Actuarial, Maths / Statistics, Engineering, Computer Science, Physics is preferred
# 1 + year experience in web or digital analytics would be highly desirable
# Proven experience in using Adobe Suite, Google Analytics and Tableau
# Experience with SQL, SAS, R or Python would be advantageous
# Proven experience of driving insights from data and presenting the findings to different sets of stakeholders
# Must be technically strong in Microsoft Suite
# Strong written and verbal communication skills
# If this sounds of interest to you, please call Sophie Monaghan immediately on 02 9270 2603 or APPLY via the link
# IMPORTANT: By submitting your email address and any other personal information when you APPLY to a job, you consent to such information being collected, held, used and disclosed in accordance with our COLLECTIONS NOTICE and PRIVACY POLICY.
# http://www.bluefinresources.com.au/privacy-policy
#
# www.bluefinresources.com.au
#
# 18
#
# Senior Analyst - Quantitative Analyst
# Based at Macquarie Headquarters, Sydney – our Quantitative Applications Division team has global responsibility for ensuring the integrity of key financial models used by Macquarie.
# In this role, you will participate in a broad range of modelling work, including validation of credit risk, market risk and other models across the Group. You will also maintain efficient communication with model owners and other Risk Management
#  Group stakeholders regarding modelling and evaluation of model performance.
# The role provides the opportunity to be a part of a team that thrives on cross skilling, ensuring that your skill set and knowledge is stretched and developed.
# The Quantitative Applications Division utilises a range of analytic techniques including: simulations, regression analysis, optimisation and time series. These are implemented using a variety of computing technologies including: C++ (OO programming),
#  R, Python, VBA, Excel, MATLAB, Mathematica.
# We will provide unique in-house training to enhance your modelling skills. Bring with you a demonstrated proficiency in solving problems and applying analytical techniques, plus a willingness to learn the others, and you will excel in this role.
# This role will suit you, if you can bring a degree in a relevant discipline, a genuine interest in finance markets, and demonstrated quantitative skills. Good programming skills would be an advantage.
# If this sounds like you, we encourage you to apply online today. For more information, please visit www.macquarie.com/careers
# Risk Management Group is an independent, centralised unit responsible for ensuring all risk across Macquarie are appropriately assessed and managed. Its divisions include Credit, Prudential, Capital and Markets, Market Risk, Operational Risk,
#  Compliance, Quantitative Applications and Internal Audit.
# Macquarie understands the importance of diversity and inclusion - our long history of success has come from being different. At Macquarie we value the innovation and creativity that diversity of thought brings. The one thing we all have in common
#  is our focus on high performance. If you're capable, motivated and can deliver, we want you on our team.
# We facilitate a range of flexible working arrangements within our teams. Talk to us about what flexibility may be available.
#
#
#
# 19
# Data Scientist - AustraliaMore jobs from this companyJob DescriptionJob HeaderData Scientist - AustraliaAdvertiser: DataikuMore jobs from this companyJob InformationJob Listing Date21 Feb 2019LocationSydney, CBD, Inner West & Eastern SuburbsSalary$120,000 - $139,999Work TypeFull TimeClassificationScience & Technology, Mathematics, Statistics & Information SciencesPlease apply for this position before March 20th 2019. After this date, your application will no longer be considered. We're looking for a Data Scientist to join our team in Australia. This position should be based in Sydney. At Dataiku, you will help our customers to build data science applications -- from conception to deployment. You will get hands-on experience coding in multiple languages and applying the latest big data technologies to business uses cases. Our ideal candidate is comfortable learning new languages, technologies and modeling techniques, while being able to explain their work to other data scientists and clients. Responsibilities: Construct end-to-end data flows from raw data to predictions Create user and training documentation, and conduct formal training classes Using data and process modelling techniques to help customers analyzing their data Crunch, analyze and investigate on any kind of data Explore new machine learning algorithms Build attractive visualizations Communicate results to non-technical colleagues and clients Acting as a central reference and information source in data science for the R&D and sales team Requirements You have at least a bachelor degree in data science or machine learning or mathematics 2+ years experience with R or Python 2+ years experience with predictive modeling Familiarity with data visualization in R or Javascript Understanding of relational data or SQL A first successful experience working with a software editor or in an international environnement Fluent in English Bonus points for any of these: Experience with PySpark, SparkR or Scala Experience developing WebApps Experience building APIs Experience with HDFS and NoSQL databases  Annual salary range: between 120 and 140K AUD
# 20
#
# Digital Analyst
#
# Chance to gain client side experience in leading brand
# Excellent team culture and social workplace
# Autonomous and pivotal role
# The organisation:A leading and visible brand with great work culture. One for the resumeThe role:A Digital Analyst to use the Adobe suite to report on and give insights to website performance.     Responsibilities
# Support digital and website marketing efforts, including analysing online customer behaviour, conversion optimisation, design &amp; implementation of digital tracking &amp; tagging structures – and build accurate reporting &amp; insights based
#  on these
# Work with the team to solve customer journey challenges through behavioural, qualitative analysis of website, online application and mobile app data.
# Maintain digital performance dashboards and BAU weekly/monthly reports
# Ad hoc analysis to solve stakeholder problems and identify new opportunities
# Support the development &amp; implementation of marketing campaigns, including, data selections, campaign tracking, pre- and post-campaign reviews
#  Selection criteria:
# 1+ years’ experience in delivering web analytics to stakeholders essential. Adobe is ideal but will also consider Google Analytics
# Digital marketing and media tracking knowledge
# A bonus if have experience using database extraction, processing and visualisation tools such as SQL, Tableau, Qlik, Power BI,
# Experience coding R or Python (or similar) would be an advantage
# Implementation and management of analytics tagging a plus
# Reference number: 71143 Contact name: Aidan Gavin Telephone: 02 8234 8900 Address Level 6, 46 Market Street, Sydney, NSW 2000.
#
# 21
#
# Risk Management &amp; Compliance Recruitment Solutions
# Data Manager | Newly created role | Media &amp; Advertising
# Work for a leading global media and online advertising company
# Newly created role for a Data Manager to build a team of analysts
# Competitive salary on offer | Excellent company benefits
# A leading global media and advertising company, is currently seeking an experienced Data Manager who is passionate and enthusiastic about data and how to build real value for the company. This is a newly created role and a chance to help build
#  and shape your team of data analysts and set your own strategy for the team.
# Reporting to the Head of Data and Insights you will be leading a team of highly skilled Analysts to build high-quality analytical reporting to produce actionable and sophisticated insights.
#  Key Responsibilities
# Leading, growing and developing a team of Analysts
# Acting as a thought leader for new strategic initiatives shaped by emerging technology
# Hands on technical skills and development will still be required in the role
# The ability to interpret large datasets and data mining using innovative methods
# Be a key player in leading and delivering analytical solutions
# Engage and influence C level stakeholders
# Dive deep in analysing data patterns
# Research and explore new machine learning/advanced analytics capabilities and techniques
# Implement data analysis techniques
#  Key Skills
# Proven experience in leading a team is essential
# Ability and willingness to be hands on in the delivery of highly technical data analytics projects
# Extensive experience in the application of analytics, insights and data mining to commercial "real-world" problems
# Exposure to media, consumer research or digital media analytics is desirable however not essential
# Solid skills in SQL and non-SQL
# Advanced Analytical Modelling in a business context
# Technical experience in programming in Python, R and statistical packages (R, SAS)
# Technical experience in one or more visualisation tool such as Tableau or Power BI
# Qualifications in relevant disciplines (Physics, Statistics, Mathematics, Computer Science, Analytics)
# This is an excellent opportunity to work in an agile environment to deliver high-quality analytical solutions, data assets, tools and insights. If you are an experienced leader and enjoy delivering deep insights through data analytics to support
#  key business strategies, then this could be an opportunity for you.
# This is a newly created role and an opportunity to shape and recruit your own team.
# Please apply online below or for more information contact Sophie Monaghan at Bluefin Resources on 02 9270 2603
#
# IMPORTANT: By submitting your email address and any other personal information when you APPLY to a job, you consent to such information being collected, held, used and disclosed in accordance with our COLLECTIONS NOTICE and PRIVACY POLICY.
# http://www.bluefinresources.com.au/privacy-policy
#
# www.bluefinresources.com.au
#
# 22
#
# Back End Developer
# Do you enjoy using data for social good? Interested Python programming? Fascinated by data and how it is interpreted and applied? Then this is the opportunity for you.This well-funded startup and part of an invested accelerator programme
#  are looking for a back end led data focused developer to join their team. You will be working on their data-driven platform, designed for Not for Profit, Government, and Social Sector organizations. Working with the technical team (data scientists
#  and front end developers) your role will see you bring new features and components into the data platform for exposing complex datasets, blending datasets and the storage of private datasets.This is a highly collaborative role, requiring
#  a solution finding approach with the UX/UI and technical team on feature development.Skills required:
#
# Able to work with back end technologies (JavaScript and PHP, Java or Python) to surface large datasets for multiple users and build for scaling to multiple users
# Typescript and Python experience or knowledge required
# Component and application design support in React preferred
# Experience working with Multivariate data preferred, particularly using MultiIndex in Pandas.
# Able to apply and justify React state management strategies preferred
# Ability to solve problems with back-end technologies
# This is a great opportunity for a Back End or Full Stack Developer with some Python and Data experience to grow into a leadership position and an integral part of the growing technology team in 2019. Please Apply Now! For more information.
#
#
# 23
#
# Senior Analyst
# About The Company The organisation strives to help better customer experience and personalisation. Be part of this organisation will allow you to take initiative of your own work, contributing to the overall high performance
#  working culture. The role falls under a Customer Analytics team - working closely with business stakeholders to provide analysis to enable the wider business to make strategic decisions and better their customer experience. About The Role
# Apply commercial understanding to the business problem
# Communication with stakeholders on project updates
# Drive insights and actionable recommendations from delivering analytical solutions
# Strategic type position that offers you a platform for you to develop, create and bring your own ideas to life.
# Experience Required
# 3-5 years experience working in a similar role with a statistical foundation
# Great communication and presentation skills
# Experience working with data manipulation using SQL and/or with R, Python
# University qualification in a quantitative field like statistics, computer science, actuarial etc
#
# Please APPLY NOW with a Word version of your resume.
# For further information call Emily Nota on 02 8246 7711.
#
#
# 24
#
# Data Architect - Growing Consultancy Brand
# Growing Australian Owned Consultancy6mth inital contract with potential to extendSydney CBD locationOur client, a growing consultancy business has an opportunity for an experienced Data Architect to work on-site with a dedicated
#  customer in Sydney's CBD.  The key role requriements are as follows:
#
#  5+ years proven work experience as a Data Architect or similar role.
# In-depth understanding of data classification and storage principles including SQL and non-SQL environments.
# Technical expertise regarding data acquisitions, data transformation, data models, database design development, data mining and segmentation techniques.
# Strong understanding of Data Governance including Data Classification, Data Quality, Data Lineage, Data Protection/Privacy/Security.
# Strong knowledge of, and experience with, Big Data technologies (e.g. Hadoop, noSQL, Mongo, Kafka, etc.).
# Knowledge of and experience with Big Data processing technologies (e.g. Spark with Scala / Java / Python / R).
# Tertiary degree in Computer Science, Information Systems or equivalent work experience.
# Previous experience with NSW Government Data Policies and Standards highly desirable.
# Previous experience in developing a framework for migration to the new architecture and managing and maintaining the architecture.
# The preferred candidate will be a professional, solutions focussed person with excellent interpersonal and communication skills and a high level of stakeholder engagement.To be considered for this role you will need to be based in Sydney
#  with the ability to commence work at short notice.  For a confidential discussion please contact Sharyn Saxby - sharyn.saxby@talentinternational.com.au
#
# 25
#
# 2 XSenior Data Engineer (Big Data) - FinTech - $150-170K + Super + Bonus
# Senior Data Engineer (Big Data) - Sydney CBD - $150-170K + Super + BonusOur client is a market leading, multi award winning, rapidly growing Australian FinTech innovator who dominate their niche segment within the financial services space.
#  Boasting a rapidly growing team who are focused on disrupting conventions to make financial service solutions intelligent and easy. They have an energising, supportive and collaborative culture, are receptive to new ideas and innovation, and are
#  looking for great people who want to be a part of that journey. With the business focused on optimising strategic operations by proactively leveraging key data assets a brand new position has been created for two Senior Data Engineers (Big Data)
#  to join the team.     As a Senior Data Engineer (Big Data) the core focus of this role will be to develop as series of innovative Real Time Analytics and Insights based solutions that will optimise the way organisation drives
#  it business. Projects may include;
# Analysing/Processing real-time online consumer behaviour data to drive personalisation of online customer experience and web personalisation.
# Data funnelling with new external credit data providers to support, market positioning, credit decisioning, behavioural predictions etc.
# Real time analysis/processing of customer behaviour and contact centre agent performance data to optimise customer experience.
#  Responsibilities of the role will involve but not be limited to:
# Develop a strong understanding of strategic business initiatives and apply your expertise in Data Engineering for quantitative analysis, data mining, and data visualisation to design solutions to be leveraged by the business optimise performance.
# Work with Data Scientists &amp; Business Stakeholders to understand data needs.
# Design, build and launch new data models, data definitions, ingestion, integration, and transformation processes.
# Build data expertise and own data quality for allocated areas of ownership.
# Create automated data pipelines via SQL, Tableau &amp; R/Python frameworks.
# ...
# You will have tertiary qualifications in Economics, Finance, Computer Science, Mathematics or another quantitative discipline.
#
# About ASIC
# At ASIC there is a reason for everything we do, every law we regulate, every action we take, every interaction we have with industry and consumers. We're proud of the difference we make to Australia's economic reputation and wellbeing.
# ASIC can offer you a variety of interesting and challenging work. We provide the support for our employees to develop professionally and succeed. ASIC offers a range of programs such as flexible work practices and development programs which
#  include a focus on gender equity and women in leadership.
# ASIC is committed to providing a diverse and inclusive workplace where the very best talent in Australia chooses to work. We encourage applicants from diverse backgrounds to apply, including Indigenous Australians and people with a disability.
# To work with us, you must be an Australian citizen, and be prepared to complete an ASIC Organisational Suitability Assessment (OSA) in addition to obtaining a Government Security Clearance which is issued by the Australian Government Security
#  Vetting Agency (AGSVA).
# Please view the position description for more information or click ‘apply' to start your application.
#
#
# 42
#
# SQL Data Analyst (Junior/Mid Level) :: $62K
# SQL Data Analyst (Fixed Term Contract) :: Leading international organisation :: Excellent career progression opportunities, training and company benefits. Leading international organisation based in Central Sydney are looking
#  to hire a Junior / Mid-Level Data Analyst to join their Data Quality team on a fixed term contract basis. This position is initially to cover maternity but the internal career prospects are huge in an organisation of this size with a strong desire
#  to promote internal talent.  Reporting to the Data Steward the successful candidate will play a key role in the day to day management of core data assets that support the key products sold to clients around Australia. You will work closely
#  with IT, Sales, Product and Analytics to drive data quality and coverage of each asset The main roles and responsibilities of this Sydney based Junior / Mid-Level Data Analyst are highlighted below
# Conduct data analysis
# Undertake R&amp;D analysis of Data Assets and identify areas for Data Quality improvements
# Develop and present new Data Quality opportunities
# Report on data quality issues and generate meaningful insights.
# Design and implement data new analysis processes
#     The main skills and experience needed for this Sydney based Junior / Mid-Level Data Analyst
# A minimum of 12 months commercial experience as a Data Analyst
# SQL experience
# Knowledge of R and Python
# Knowledge of Tableau
#  If this exciting opportunity is of interest, please submit your resume in the first instance
# Iain Blackburn423281112
# www.correlateresources.com
# Correlate Resources are your trusted Data Analytics Recruitment Partner Register with us to receive exclusive opportunities, industry insights and ongoing career support.
#
# 43
#
# Acturial/Pricing Analysts x3, GI, Sydney CBD
# My client is a Financial Services organisation who continue to go from strength to strength with their innovative product suite and good governance enabling them to continue growing as we move into 2019. With a nascent new Product Pricing Team
#  growing currently they are looking for talented and experienced Actuarial / Pricing Analyst’s to join their team. I am looking for applications from candidates with strong mathematically orientated academics ( BSc, MSc etc in a Maths focused
#  Degree – e.g. Economics, Statistics, Mathematics, Actuarial Studies, Operations Research et al) and at least 12m (ideally 3 years but more experienced candidates are also encouraged to apply) experience in an Analytically focused role within
#  a General Insurance team. In this role you will be working as part of a customer-facing team who provide internal consultancy to the business, supporting the execution of various strategies from a pricing perspective. With numerous initiatives
#  underway your role will require a high level of technical competency ( fluent programming /modelling skills/capabilities from a traditional tech – e.g. SQL, SAS, Emblem etc.-  and more “data science” orientated perspective – Python, R etc.)
#  as you will be involved building Actuarial and Statistical Models for innovations and solutions in the pricing arena. Candidates also need a solid understanding of the GI market locally including products &amp; services for my client as
#  well as having a decent grasp of the competitor landscape. This is an innovative Pricing team which works pretty much end to end in comparison with traditional pricing teams and they are continually looking to new technology/techniques (e.g.
#  Machine Learning techniques, AI, Data Science/Big Data approaches) in order to innovate from a Pricing perspective and deliver a competitive advantage to the business.    This is an excellent role within a team with a strong
#  and supportive culture. This is a high performance team where what you deliver will be measured along with your ability (in the fullness of time) to suggest process improvements as well as the quality of your stakeholder relationships. With
#  strong leadership which is well regarded in the industry this is an exciting time to be joining this function. With multiple roles available for the right candidate these opportunities offer successful applicants a very real chance to enjoy
#  meaningful career progression over the next 2-5 years. The team is highly visible within the business where excellent work will get recognition from key people from a Senior Management level.    In short, these roles offer
#  some of the best Pricing/Actuarial Analytical roles you are likely to find in Sydney this year. Superb opportunities. Interested candidates should apply ASAP with an up to date CV (Word Format ideally) to declan.oboyle@indmand.com.au or apply
#  via the online facility or call Declan on 0452 411 968 for a confidential discussion.
# Declan O'Boyle0452411968
#
# 44
#
# Data Analyst - Campaign Analytics
# Career development
# Pre and post campaigns
# Great Package
# One of Australia best places to work are looking for Campaigns Analyst with strong tech skills and campaigns experience. You will be working as part of an newly created team who are know it passion for development and self improvement.
# You will work closely with the marketing teams and play a key role in customer acquisition and retention. Analytics is really high profile and this is not a role where you will be sitting in the corridor you have the ability work with senior stakeholders
#  play a key role in pushing the business forward.
# The ideal candidate will have:
# Experienced in building end to end campaigns
# Strong SQL experience is essential
# 2+ years experience, ideally in campaigns
# SAS, R or Python experience will be highly regarded
# Can do attitude with the ability to hit the ground running
# Strong stakeholder management skills
# Excellent analytical skills and attention to detail
# Ability to manage projects and processes to deadlines in a dynamic environment
# Experience in campaigns is highly desirable
#
# Duties
# Working on campaigns from end to end and so experience with pre and post campaigns
# Analyse and review strategies and make recommendations in order to improve the performance
# Manage the research of the market and you will present it to stakeholders
# post-campaign analysis for all our campaigns, and deliver actionable insights and recommendations
# Identify opportunities to improve the efficiency of the targeting campaigns
# If this sounds like the role for you apply now! Please note only candidates with full working rights and are currently in Australia will be considered. For a chat about the market or career options get in touch with Leon on lyoung@morganmckinley.com.au
#  or 0289863147
# Morgan McKinley is acting as an Employment Agency in relation to this vacancy.
#
#
# 45
#
# Quant Developer (Modern C++, Python and Java) - Leading Australian Bank
# You will be solving complex problems that can only be found in the Financial Markets. Being a Quantitative Developer within the Data Team you will have a major impact in helping to drive the data driven organization forward. You can expect to
#  work on multiple projects have an affect on nearly every aspect of the firm. They are looking to solve the toughest problem in trading strategy/development, machine learning and data infrastructure.
# Duties:
# Identify and define algorithm improvements
# Create models to capture complex behavior of the financial markets
# Implement frameworks for developing, validating and testing trading strategies
# Architect, implement and improve tools that build and interact with our diverse data sets
# Develop tools for monitoring and validating the trading system performance
# Drive technical innovation within the team through the evaluation of new tools and technologies
# Qualities that make a great candidate:
# BS/MS/PhD in technical field – Physics, Math, Engineering, Computer Science, or equivalent
# 2+ years of professional experience in developing software applications in Python on Linux
# Highly motivated
# Passionate, pragmatic problem solver with the ability to both independently and collaboratively pursue solutions to complex problems
# Ability to communicate complex technical topics in a clear and concise way
# Demonstrated experience working with diverse data sets across multiple domains
# Demonstrated experience using software engineering best practices to deliver complex software projects
# Experience with the common Python data libraries
#
#
#
#
# 46
# Data Analyst/ScientistMore jobs from this companyJob DescriptionJob HeaderData Analyst/ScientistAdvertiser: Austcorp ExecutiveMore jobs from this companyJob InformationJob Listing Date8 Feb 2019LocationSydney, CBD, Inner West & Eastern SuburbsSalary$110k Package + BenefitsWork TypeFull TimeClassificationScience & Technology, Mathematics, Statistics & Information SciencesAustCorp Executive are searching for a Data Analyst or Junior Data Scientist to join our marketing client that develop data driven insights on a global scale.The Client:One of Australia's largest media agencies that have a huge global presence.The Role:A Data Analyst or Junior Data Scientist that will be helping clients across various industries. You will analyse large data sets to develop insights as to how clients advertising is interpreted across multiple channels and devices.Key Requirements: Bachelors Degree in Mathematics or related field 2 years Data Scientist experience or 4+ years Data Analyst experience Proven data/statistical modelling & machine learning experience Solid knowledge of one of the following data science languages	 Python, Scala or R Sound SQL capabilities Media technology experience  Excellent communication skillsHighly Desirable: PhD qualified Marketing science experience Experience with any of the following: AWS, Spark, Hadoop or Redshift Power BI or Tableau experienceTenure - PermanentTo apply please send your CV to Ari Hayton by clicking the 'Apply Now' button below. AustCorp provides equal employment opportunities  to all employees and applicants for employment in accordance with federal and state laws.  Right to live and workYou must have the right to live and work in this location to apply for this job.
# 47
#
# Actuary/actuarial analyst
# This newly created role for a Senior Pricing Analyst based in Hobart, will support the pricing lead in investigating, developing and maintaining this organisations suite of Pricing activities.The key elements of the role are to:
# undertake premium, rate and natural perils pricing reviews
# Improve the efficiency and breadth of current pricing/portfolio team
# Support the leadership of Portfolio and Pricing projects and activity as required to meet strategic goals
# Support the development of periodic reporting
# Troubleshoot complex data issues, recommend solutions, perform interesting analysis
# Support the development of a winning culture
#  To be successful in this role, it is anticipated that you will:
# Have approx 5-8 years working experience mainly gained within a personal lines pricing team
# Actuarial qualifications or similar
# A keen interest in learning R, Python etc.  Existing knowledge of EMBLEM/Radar welcomed
# High level analytical skills with developed business acumen and a pragmatic appreciation of the 'big picture'.
# Keen customer focus
# Solutions and outcomes orientated
# Emphasis on continuing personal development
# Enjoy being part of a dynamic team
# Adaptable and able to deal with ambiguity
# Have strong influencing skills
# Have an entrepreneurial mindset
#  You MUST have working rights for Australia to apply for this position.For more information please contact Lesley.traverso@talentinsights.com.au or 0433 129390
# Lesley Traverso0433 129390
#
# 48
# Data Analyst - Permanent Opportunity - R expertMore jobs from this companyJob DescriptionJob HeaderData Analyst - Permanent Opportunity - R expertAdvertiser: InfopeopleMore jobs from this companyJob InformationJob Listing Date6 Feb 2019LocationSydney, CBD, Inner West & Eastern SuburbsSalarynegotiable based on experienceWork TypeFull TimeClassificationInformation & Communication Technology, Database Development & AdministrationI am looking for a Data Analyst with a minimum of 2+ years of commercial hands-on experience in analysis of data,  to be part of a client based in prime location in CBD.What you'll be doing in this role: Explore large datasets, discover trends and patterns and extract insights Develop scripts to extract and analyse large data sets Design / Generate Reports and dashboards Implement test cases and verify scripts and models to ensure the accuracy of the results Extract data from external sources Your experience and skills: Only Australian Citizens are eligible to apply for this role - mandatory Commercial experience in SQL for data extraction and manipulation - mandatory Hands-on experience in R  - mandatory Strong analytical skills coupled with great attention to detail Inquisitive by nature Ability to acquire in-depth knowledge of healthcare data - previous experience in healthcare analytics will be highly regarded - preferred, not mandatory Ability to work, both independently and as part of a team Feel free to share with us your GitHub, Kaggle or any other details which you feel might help your application.This is an immediate start role and selection process is very quick, so local Sydney candidates will be preferred with 1-2 weeks notice period.Due to the nature of work, you need to be an Australian citizen and be ready for baseline security clearance to be considered for the role.Please note: Only shortlisted candidates will be contacted for further screening.The application form will include these questions:Which of the following statements best describes your right to work in Australia?How much notice are you required to give your current employer?Do you hold Australian Security Clearance?How many years' experience do you have as a data analyst?
# 49
#
# Data Scientist - Immediately Available
# 3/4 months contract
# Must be immediately available
# CBD location
#
# Looking for an immediately available data scientist for a contract role in Sydney CBD
# Desired experience and skill set
# 3-5 years of data science experience
# Advanced quantitative degree - Math, Stats, Computer Science, Engineering, etc
# Proficient in SQL and Python a must, R would be nice too
# Experience with predictive models using ML (Random Forrest, Regression, Gradient Boosting, Cluster analysis)
# Familiarity with application to behavioral and customer segmentation, and usage and demand forecasting
# TMT experience a nice to have, but not a deal breaker
# Key Information
# Project length: 3/4 months, with the potential of rolling on
# Location: Sydney
#
# jobs.hudson.com
# Specialist Recruitment | Talent Management
